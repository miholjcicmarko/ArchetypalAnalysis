# %%
import pandas as pd
import numpy as np
import py_pcha
from py_pcha import PCHA
import matplotlib.pyplot as plt
from numpy.matlib import repmat

# %%
data=pd.read_csv("/Users/markomiholjcic/Downloads/mnist_aa_embeddings/embeddings.csv")
data
# Out:
#             image_name                                         embeddings
# 0        digit-000.png  [0.05391351 0.07404405 0.13674922 0.4255966  0...
# 1        digit-001.png  [0.61366886 0.02680839 0.07571347 0.01089691 0...
# 2        digit-002.png  [0.06098959 0.02744945 0.4997878  0.16454944 0...
# 3        digit-003.png  [0.07347756 0.04593835 0.10082413 0.081952   0...
# 4        digit-004.png  [0.01037837 0.11390355 0.06867444 0.0409117  0...
# ...                ...                                                ...
# 69995  digit-69995.png  [0.05480497 0.04671353 0.44115025 0.04830631 0...
# 69996  digit-69996.png  [0.01761035 0.02564309 0.01838804 0.0457973  0...
# 69997  digit-69997.png  [0.04164894 0.11889447 0.01580404 0.06976292 0...
# 69998  digit-69998.png  [0.02188791 0.07191634 0.02957529 0.01741717 0...
# 69999  digit-69999.png  [0.02564842 0.07666068 0.03877746 0.10907381 0...
#
# [70000 rows x 2 columns]

# %%
def check_float(potential_float):
    try:
        float(potential_float)
        return True
    except ValueError:
        return False

# %%
a = data["embeddings"][0].split()
a[8]
# Out:
# '0.1994106'

# %%
df_arch = pd.DataFrame()

for i in range(int(len(data["embeddings"]))):
    a = data["embeddings"][i].split()
    newdf = []
    for j in range(10):
        index = str(j)
        if (j == 0 and check_float(a[j][1:]) == True):
            newdf.append(a[j][1:])
        elif (j == 9 and check_float(a[j][:-1]) == True):
            newdf.append(a[j][:-1])
        elif (check_float(a[j])):
            newdf.append(a[j])
    newdf = np.array(newdf)
    newdf = pd.DataFrame(newdf)
    df_arch = pd.concat([df_arch, newdf], axis = 1, ignore_index=True)
    
df_arch
# Out:
#         0           1           2           3           4           5      \
# 0  0.05391351  0.61366886  0.06098959  0.07347756  0.01037837   0.0459867
# 1  0.07404405  0.02680839  0.02744945  0.04593835  0.11390355  0.04515992
# 2  0.13674922  0.07571347   0.4997878  0.10082413  0.06867444  0.61563224
# 3   0.4255966  0.01089691  0.16454944    0.081952   0.0409117  0.01063449
# 4   0.0411199  0.06401073  0.02861577  0.12600893  0.09087378  0.02138487
# 5  0.02759214  0.08459084  0.01750394  0.04894172  0.07866877   0.0648674
# 6  0.01221162  0.03371251  0.00477693  0.02826568  0.48221716  0.04112532
# 7  0.02482197  0.02214387  0.03465103  0.09109855  0.04286538  0.03999878
# 8   0.1994106  0.05600829  0.13894095  0.03097786  0.00752622  0.07063857
# 9  0.00454039  0.01244616  0.02273515  0.37251526  0.06398069  0.04457176
#
#         6           7           8           9      ...       69990  \
# 0  0.03238064  0.01309529  0.01598776  0.18204509  ...   0.0134103
# 1  0.03840548  0.02758342   0.0254217  0.05660053  ...  0.07027481
# 2  0.07282451  0.03506592  0.08271434  0.08963118  ...  0.01435665
# 3  0.28988287  0.13544765  0.10028924  0.18337789  ...  0.11746617
# 4  0.07476216  0.09476285  0.07835905  0.07624219  ...  0.03541357
# 5   0.0791451   0.5201363  0.01160002  0.08008884  ...   0.4845779
# 6  0.04455604  0.03812464   0.6142941   0.1274361  ...  0.02005448
# 7  0.08454224  0.05197895  0.03993481  0.04348837  ...   0.0643241
# 8  0.19701257  0.03115428  0.01430812  0.11565237  ...  0.15582524
# 9  0.08648837  0.05265067    0.017090  0.04543746  ...  0.02429686
#
#         69991       69992       69993       69994       69995       69996  \
# 0   0.0909965  0.07600717  0.06722315  0.01283924  0.05480497  0.01761035
# 1  0.01473779  0.05928926   0.0601532  0.02202072  0.04671353  0.02564309
# 2  0.01917254  0.21188357  0.02381524  0.49006608  0.44115025  0.01838804
# 3  0.03275465  0.03310212  0.01606729  0.25495008  0.04830631   0.0457973
# 4  0.12099818  0.10073654  0.02767293  0.02455335  0.06493087  0.00875955
# 5  0.01559401  0.12571633  0.65678674  0.06193805   0.0331267  0.02353934
# 6  0.43401474  0.04060297  0.08181965  0.01381346  0.03472365  0.04952309
# 7  0.01965479  0.04847971  0.02386118  0.05662821  0.11151236  0.75315946
# 8  0.18795551  0.28907335  0.01444672  0.04269127  0.15084116  0.01041309
# 9  0.06412122  0.01510896  0.02815389  0.02049957    0.013890  0.04716673
#
#         69997       69998       69999
# 0  0.04164894  0.02188791  0.02564842
# 1  0.11889447  0.07191634  0.07666068
# 2  0.01580404  0.02957529  0.03877746
# 3  0.06976292  0.01741717  0.10907381
# 4  0.44824505  0.02982045  0.17195566
# 5  0.03551341  0.01308583   0.1663636
# 6  0.11129064  0.04130688  0.02455133
# 7  0.08140196  0.28501353  0.26238188
# 8  0.03457187   0.1405764  0.04127214
# 9  0.04286668    0.349400  0.08331497
#
# [10 rows x 70000 columns]

# %%
df_arch.to_csv('/Users/markomiholjcic/Documents/GitHub/ArchetypalAnalysis/data/MNISTSMatrix10.csv', index = False, header = True)

# %%
data_id = data.drop(columns= ["embeddings"])
data_id = data_id.rename(columns = {"image_name":"id"})
data_id
# Out:
#                     id
# 0        digit-000.png
# 1        digit-001.png
# 2        digit-002.png
# 3        digit-003.png
# 4        digit-004.png
# ...                ...
# 69995  digit-69995.png
# 69996  digit-69996.png
# 69997  digit-69997.png
# 69998  digit-69998.png
# 69999  digit-69999.png
#
# [70000 rows x 1 columns]

# %%
data_id.to_csv('/Users/markomiholjcic/Documents/GitHub/ArchetypalAnalysis/data/MNISTSImageMatrix.csv', index = False, header = True)
