# %%
import pandas as pd
import numpy as np
import py_pcha
from py_pcha import PCHA
import matplotlib.pyplot as plt
from numpy.matlib import repmat

# %%
data=pd.read_csv("/Users/markomiholjcic/Downloads/mnist_aa_embeddings/embeddings.csv")
data
# Out:
#             image_name                                         embeddings
# 0        digit-000.png  [0.05391351 0.07404405 0.13674922 0.4255966  0...
# 1        digit-001.png  [0.61366886 0.02680839 0.07571347 0.01089691 0...
# 2        digit-002.png  [0.06098959 0.02744945 0.4997878  0.16454944 0...
# 3        digit-003.png  [0.07347756 0.04593835 0.10082413 0.081952   0...
# 4        digit-004.png  [0.01037837 0.11390355 0.06867444 0.0409117  0...
# ...                ...                                                ...
# 69995  digit-69995.png  [0.05480497 0.04671353 0.44115025 0.04830631 0...
# 69996  digit-69996.png  [0.01761035 0.02564309 0.01838804 0.0457973  0...
# 69997  digit-69997.png  [0.04164894 0.11889447 0.01580404 0.06976292 0...
# 69998  digit-69998.png  [0.02188791 0.07191634 0.02957529 0.01741717 0...
# 69999  digit-69999.png  [0.02564842 0.07666068 0.03877746 0.10907381 0...
#
# [70000 rows x 2 columns]

# %%
def check_float(potential_float):
    try:
        float(potential_float)
        return True
    except ValueError:
        return False

# %%
a = data["embeddings"][0].split()
a[8]
# Out:
# '0.1994106'

# %%
df_arch = pd.DataFrame()

for i in range(200):
    a = data["embeddings"][i].split()
    newdf = []
    for j in range(10):
        index = str(j)
        if (j == 0 and check_float(a[j][1:]) == True):
            newdf.append(a[j][1:])
        elif (j == 9 and check_float(a[j][:-1]) == True):
            newdf.append(a[j][:-1])
        elif (check_float(a[j])):
            newdf.append(a[j])
    newdf = np.array(newdf)
    newdf = pd.DataFrame(newdf)
    df_arch = pd.concat([df_arch, newdf], axis = 1, ignore_index=True)
    
df_arch
# Out:
#           0           1           2           3           4           5    \
# 0  0.05391351  0.61366886  0.06098959  0.07347756  0.01037837   0.0459867
# 1  0.07404405  0.02680839  0.02744945  0.04593835  0.11390355  0.04515992
# 2  0.13674922  0.07571347   0.4997878  0.10082413  0.06867444  0.61563224
# 3   0.4255966  0.01089691  0.16454944    0.081952   0.0409117  0.01063449
# 4   0.0411199  0.06401073  0.02861577  0.12600893  0.09087378  0.02138487
# 5  0.02759214  0.08459084  0.01750394  0.04894172  0.07866877   0.0648674
# 6  0.01221162  0.03371251  0.00477693  0.02826568  0.48221716  0.04112532
# 7  0.02482197  0.02214387  0.03465103  0.09109855  0.04286538  0.03999878
# 8   0.1994106  0.05600829  0.13894095  0.03097786  0.00752622  0.07063857
# 9  0.00454039  0.01244616  0.02273515  0.37251526  0.06398069  0.04457176
#
#           6           7           8           9    ...         190  \
# 0  0.03238064  0.01309529  0.01598776  0.18204509  ...  0.01056832
# 1  0.03840548  0.02758342   0.0254217  0.05660053  ...  0.10751773
# 2  0.07282451  0.03506592  0.08271434  0.08963118  ...  0.01638899
# 3  0.28988287  0.13544765  0.10028924  0.18337789  ...  0.01623498
# 4  0.07476216  0.09476285  0.07835905  0.07624219  ...  0.07738732
# 5   0.0791451   0.5201363  0.01160002  0.08008884  ...  0.00798991
# 6  0.04455604  0.03812464   0.6142941   0.1274361  ...   0.5882332
# 7  0.08454224  0.05197895  0.03993481  0.04348837  ...  0.06904805
# 8  0.19701257  0.03115428  0.01430812  0.11565237  ...  0.09547472
# 9  0.08648837  0.05265067    0.017090  0.04543746  ...  0.01115677
#
#           191         192         193         194         195         196  \
# 0  0.11415247  0.04674096  0.13324104   0.2723023  0.05098432  0.00906346
# 1  0.07301403  0.61746913  0.01710021  0.01294319  0.05895155   0.5490333
# 2  0.00671397  0.06454182  0.09720638  0.02176541  0.07943464  0.11096269
# 3  0.00927899  0.02421955  0.07542694   0.4809254  0.04911274  0.01402715
# 4  0.00509001  0.02667337  0.05975236   0.0521415  0.03254903  0.02345427
# 5  0.07218833  0.01276915  0.03577997   0.0676857  0.04671364  0.04787591
# 6   0.0151202  0.05872585  0.02666736  0.01584164  0.01799725   0.0518304
# 7  0.00578495  0.03337248  0.42400986  0.04631448  0.02959559  0.03340411
# 8  0.68000865  0.07656215  0.01524075  0.01785457  0.01807102  0.08881958
# 9    0.018648  0.03892546  0.11557503  0.01222579  0.61659026  0.07152919
#
#           197         198         199
# 0  0.04625066  0.08786941  0.01906033
# 1  0.06291524  0.04190565  0.03983253
# 2  0.08160185  0.09357324  0.06337439
# 3  0.12593217   0.4385587  0.09049715
# 4  0.14897996  0.06710702  0.05407629
# 5  0.09012074  0.02957621   0.3988179
# 6  0.02624578  0.01449656  0.09321873
# 7  0.02377065  0.04315863  0.05426313
# 8  0.31783387  0.12059326   0.0430791
# 9  0.07634904  0.06316131  0.14378054
#
# [10 rows x 200 columns]

# %%
df_arch.to_csv('/Users/markomiholjcic/Documents/GitHub/ArchetypalAnalysis/data/MNISTSMatrix10_200.csv', index = False, header = True)

# %%
df_arch.to_csv('/Users/markomiholjcic/Documents/GitHub/ArchetypalAnalysis/data/MNISTSMatrix10.csv', index = False, header = True)

# %%
data_id = data.drop(columns= ["embeddings"])
data_id = data_id.rename(columns = {"image_name":"id"})
data_id = data_id[:200]

# %%
data_id
# Out:
#                 id
# 0    digit-000.png
# 1    digit-001.png
# 2    digit-002.png
# 3    digit-003.png
# 4    digit-004.png
# ..             ...
# 195  digit-195.png
# 196  digit-196.png
# 197  digit-197.png
# 198  digit-198.png
# 199  digit-199.png
#
# [200 rows x 1 columns]

# %%
data_id.to_csv('/Users/markomiholjcic/Documents/GitHub/ArchetypalAnalysis/data/MNISTSImageMatrix_200.csv', index = False, header = True)
